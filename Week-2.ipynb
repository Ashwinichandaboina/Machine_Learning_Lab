# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Car_sales.csv")

# %%
df.head(5)
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
print(len(df))
# Out:
# 157

# %%
df.shape[0]
# Out:
# 157

# %%
df.shape[1]
# Out:
# 15

# %%
df.drop_duplicates()
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.shape[0]
# Out:
# 157

# %%
df.shape[1]
# Out:
# 15

# %%
df.describe()
# Out:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
max=df.isnull().sum().idxmax()
df=df.drop(columns=[max])
df
# Out:
#                  Model  Sales in thousands 4-year resale value Vehicle type  \
# 0    Integra                        16.919               16.36    Passenger
# 1    TL                             39.384              19.875    Passenger
# 2    CL                             14.114              18.225    Passenger
# 3    RL                              8.588              29.725    Passenger
# 4    A4                             20.397              22.255    Passenger
# ..                 ...                 ...                 ...          ...
# 152  V40                             3.545                   .    Passenger
# 153  S70                            15.245                   .    Passenger
# 154  V70                            17.531                   .    Passenger
# 155  C70                             3.493                   .    Passenger
# 156  S80                            18.969                   .    Passenger
#
# ...

# %%
df.shape
# Out:
# (157, 15)

# %%
cols=df.select_dtypes(include=['object']).columns
df_cleaned=df.dropna(subset=cols)
print(df_cleaned)
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df_sorted=df.sort_values(by='Price in thousands',ascending=True)
df_sorted
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 2    Acura          CL                             14.114              18.225
# 33   Chrysler       Town & Country                 53.480               19.54
# 129  Saturn         SL                             80.620                 9.2
# 140  Toyota         Tacoma                         84.087               9.575
# 63   Hyundai        Elantra                        66.692               7.825
# ..             ...                ...                 ...                 ...
# 126  Porsche        Carrera Cabriolet               1.866               67.55
# 95   Mercedes-Benz  SL-Class                        3.311                58.6
# 99   Mercedes-Benz  CL500                           0.954                   .
# 26   Chevrolet      Metro                          21.855                5.16
# 62   Hyundai        Accent                         41.184                5.86
#
# ...

# %%
df_sorted.head(1)
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 2  Acura          CL                             14.114              18.225
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 2    Passenger                  .         3.2        225     106.9  70.6
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 2    192        3.47          17.2              26      1-Apr-14

# %%
df_sorted.tail(1)
# Out:
#      Manufacturer              Model  Sales in thousands 4-year resale value  \
# 62  Hyundai        Accent                         41.184                5.86
#
#    Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 62    Passenger              9.699         1.5         92      96.1  65.7
#
#    Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 62  166.7        2.24          11.9              31      9-Oct-14

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
def find_min_max(df):
 return pd.DataFrame({
     'Min':df.min(numeric_only=True),
     'Max' :df.max(numeric_only=True)
 })

# %%
result=find_min_max(df)
print(result)
# Out:
#                      Min      Max
# Sales in thousands  0.11  540.561

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
object_cols = df.select_dtypes(include='object').columns
min_max = pd.DataFrame({
    'Min': df[object_cols].min(),
    'Max': df[object_cols].max()
})

print(min_max)
# Out:
#                                Min                Max
# Manufacturer         Acura              Volvo
# Model                        3-Sep  Xterra
# 4-year resale value              .               9.85
# Vehicle type                   Car          Passenger
# Price in thousands               .              9.699
# Engine size                      .                  8
# Horsepower                       .                 92
# Wheelbase                        .               99.8
# Width                            .               79.9
# Length                           .              224.5
# Curb weight                      .              5.572
# Fuel capacity                    .                 32
# Fuel efficiency                  .                 45
# Latest Launch             1-Apr-14           9-Oct-14

# %%
def find_min_max(df):
 return pd.DataFrame({
     'Min':df.min(),
     'Max':df.max()
 })

# %%
result=find_min_max(df)
print(result)
# Out:
#                                Min                Max
# Manufacturer         Acura              Volvo
# Model                        3-Sep  Xterra
# Sales in thousands            0.11            540.561
# 4-year resale value              .               9.85
# Vehicle type                   Car          Passenger
# Price in thousands               .              9.699
# Engine size                      .                  8
# Horsepower                       .                 92
# Wheelbase                        .               99.8
# Width                            .               79.9
# Length                           .              224.5
# Curb weight                      .              5.572
# Fuel capacity                    .                 32
# Fuel efficiency                  .                 45
# Latest Launch             1-Apr-14           9-Oct-14

# %%
cols=['Horsepower','Length','Fuel efficiency']
result=find_min_max(df[cols])
print(result)
# Out:
#                 Min    Max
# Horsepower        .     92
# Length            .  224.5
# Fuel efficiency   .     45

# %%
import matplotlib.pyplot as plt

# %%
df[['Price in thousands','Sales in thousands','Horsepower','Fuel efficiency']].hist(bins=30,figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
fig,axs=plt.subplots(2,2,figsize=(12,10))
axs[0,0].hist(df['Price in thousands'],bins=5,color='pink')
axs[0,0].set_title('price')
axs[0,0].set_xlabel('price')
axs[0,0].set_ylabel('frequency')
axs[0,1].hist(df['Sales in thousands'],bins=10,color='blue')
axs[0,1].set_title('sales')
axs[0,1].set_xlabel('sales')
axs[0,1].set_ylabel('frequency')

axs[1,0].hist(df['Horsepower'],bins=30,color='orchid')
axs[1,0].set_title('Horsepower')
axs[1,0].set_xlabel('horsepower')
axs[1,0].set_ylabel('frequency')
axs[1,1].hist(df['Fuel efficiency'],bins=10,color='red')
axs[1,1].set_title('Fuel efficiency')
axs[1,1].set_xlabel('fuel')
axs[1,1].set_ylabel('frequency')

plt.show()

# %%
import seaborn as sns
df['Length']=pd.to_numeric(df['Length'],errors='coerce')
sns.kdeplot(df['Length'],fill=True,color='skyblue')
plt.show()

# %%
from scipy.stats import gaussian_kde
df.columns=df.columns.str.strip()
if 'Length' in df.columns:
    df['Length']=pd.to_numeric(df['Length'],errors='coerce')
    data=df['Length'].dropna()
    kde=gaussian_kde(data)
    density_values=kde.evaluate(data)
    result=pd.DataFrame({'Length':data,'Density':density_values})
    print(result)
else:
    print('error')
# Out:
#      Length   Density
# 0     172.4  0.016206
# 1     192.9  0.027570
# 2     192.0  0.028122
# 3     196.6  0.023728
# 4     178.0  0.023772
# ..      ...       ...
# 152   176.6  0.022591
# 153   185.9  0.027308
# 154   186.2  0.027466
# 155   185.7  0.027202
# 156   189.8  0.028651
#
# [156 rows x 2 columns]

# %%
manufacturer_counts=df.groupby('Manufacturer').size().reset_index(name='Count')
print(manufacturer_counts)
# Out:
#      Manufacturer  Count
# 0   Acura              4
# 1   Audi               3
# 2   BMW                3
# 3   Buick              4
# 4   Cadillac           5
# 5   Chevrolet          9
# 6   Chrysler           7
# 7   Dodge             11
# 8   Ford              11
# 9   Honda              5
# 10  Hyundai            3
# 11  Infiniti           1
# 12  Jaguar             1
# 13  Jeep               3
# 14  Lexus              6
# 15  Lincoln            3
# 16  Mercedes-Benz      9
# 17  Mercury            6
# 18  Mitsubishi         7
# 19  Nissan             7
# 20  Oldsmobile         6
# 21  Plymouth           4
# 22  Pontiac            6
# 23  Porsche            3
# 24  Saab               2
# 25  Saturn             5
# 26  Subaru             2
# 27  Toyota             9
# 28  Volkswagen         6
# 29  Volvo              6

# %%
df.columns.str.strip()
numerical_columns=df.select_dtypes(include=['number']).columns
numerical_columns=(col for col in numerical_columns if col!='Manufacturer')
if 'Manufacturer' in df.columns:
    for col in numerical_columns:
        sns.boxplot(x='Manufacturer',y=col,data=df)
        plt.xlabel('Manufacturee')
        plt.ylabel(col)
        plt.xticks(rotation=45)
        plt.show()
    else:
        print("error")
# Out:
# error

# %%
df.columns=df.columns.str.lower()
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x=df['manufacturer'],y=df['sales in thousands'])
plt.show()

# %%
df.columns
# Out:
# Index(['manufacturer', 'model', 'sales in thousands', '4-year resale value',
#        'vehicle type', 'price in thousands', 'engine size', 'horsepower',
#        'wheelbase', 'width', 'length', 'curb weight', 'fuel capacity',
#        'fuel efficiency', 'latest launch'],
#       dtype='object')

# %%
correlation=df['sales in thousands'].corr(df['price in thousands'])
print(correlation)
# Out:
# -0.30473445412941225

# %%
df['sales in thousands']=pd.to_numeric(df['sales in thousands'],errors='coerce')
df['price in thousands']=pd.to_numeric(df['price in thousands'],errors='coerce')
df_cleaned=df.dropna(subset=['sales in thousands','price in thousands'])
correlation=df['price in thousands'].corr(df['sales in thousands'])
print(correlation)

# %%
manufacturer_counts=df.groupby('manufacturer').size().reset_index(name='Count')
print(manufacturer_counts)

# %%
numerical=df.select_dtypes(include=['number']).columns
print(numerical)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df_cleaned,x='sales in thousands',y='price in thousands')
plt.title("bhjk")
plt.xlabel('sales')
plt.ylabel('price')
plt.show()

# %%
sns.pairplot(df_cleaned,diag_kind='kde',corner=True)

plt.show()

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df['fuel efficiency'] = pd.to_numeric(df['fuel efficiency'], errors='coerce')


pairplot_data = df[['price in thousands', 'sales in thousands', 'horsepower', 'fuel efficiency']].dropna()


sns.pairplot(pairplot_data, diag_kind='kde', corner=True)
plt.suptitle("Pair Plot of Car Features", y=1.02)
plt.show()

# %%
df['sales in thousands'] = pd.to_numeric(df['sales in thousands'], errors='coerce')
df['price in thousands'] = pd.to_numeric(df['price in thousands'], errors='coerce')


df_cleaned = df.dropna(subset=['sales in thousands', 'price in thousands'])


plot_data = df_cleaned[['sales in thousands', 'price in thousands']]


correlation = plot_data['price in thousands'].corr(plot_data['sales in thousands'])
print(f"Correlation: {correlation:.2f}")


sns.pairplot(plot_data, diag_kind='kde', corner=True)
plt.suptitle("Pair Plot: Price vs Sales", y=1.02)
plt.show()
# Out:
# Correlation: -0.30

# %%
df_box=df.dropna(subset=['sales in thousands','manufacturer'])
sns.boxplot(x='manufacturer',y='sales in thousands',data=df_box)
plt.show()

# %%
df_select=df.select_dtypes(include=['number']).columns
for col in df_select:
    sns.boxplot(x='manufacturer',y=col,data=df)
    plt.show()

# %%
df_select = df.select_dtypes(include=['number']).columns

for col in df_select:
    plt.figure(figsize=(14, 6))
    sns.boxplot(x='manufacturer', y=col, data=df)
    plt.xticks(rotation=45)
    plt.title(f'Boxplot of {col} by Manufacturer')
    plt.xlabel('Manufacturer')
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()

# %%
y=df['sales in thousands']
x=df.drop(columns=['sales in thousands'])
x.shape
# Out:
# (157, 14)

# %%
y.shape
# Out:
# (157,)

# %%
from sklearn.preprocessing import LabelEncoder
x_encoded=x.copy()
le=LabelEncoder()
for col in x_encoded.select_dtypes(include=['object']).columns:
    x_encoded[col]=le.fit_transform(x_encoded[col])

print(x_encoded)
# Out:
#      manufacturer  model  4-year resale value  vehicle type  \
# 0               0     79                   53             1
# 1               0    143                   70             1
# 2               0     25                   63             1
# 3               0    115                   87             1
# 4               1      8                   78             1
# ..            ...    ...                  ...           ...
# 152            29    148                    0             1
# 153            29    125                    0             1
# 154            29    149                    0             1
# 155            29     24                    0             1
# 156            29    126                    0             1
#
#      price in thousands  engine size  horsepower  wheelbase  width  length  \
# 0                 21.50            4       140.0          5      9   172.4
# 1                 28.40           16       225.0         36     32   192.9
# ...

# %%
X = df.drop(columns=['sales in thousands'])
y = df['sales in thousands']

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sklearn.model_selection import train_test_split
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
# NameError: name 'X' is not defined
